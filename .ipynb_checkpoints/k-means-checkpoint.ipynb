# %% [markdown]
# # K-Means Clustering on User Behavior

# %% [markdown]
# 11.6 接下来的工作
#
# - spider: 用min maxin normalize each metrice
# - bar
#
# 加入user profile后
# - 每个count 转换为 ratio
# - 用整个dataset的ratio整体做baseline参考
#
# - credit_bucket: 用mean代替，转化为continuous；用lineplot 而不是 barplot

# %%
from sklearn.cluster import KMeans
import numpy as np

import pandas as pd
pd.set_option('display.float_format', lambda x: '%.5f' % x)
from scipy import stats
import matplotlib.pyplot as plt
from math import pi
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import seaborn as sns
# %matplotlib inline

# %%
userengagement_df = pd.read_csv("../dataset/user_engagement.csv")
userengagement_df['session_start_timestamp'] = pd.to_datetime(userengagement_df['session_start_timestamp'])
#first_session['user_signup_timestamp'] = pd.to_datetime(first_session['user_signup_timestamp'])
#first_session['action_timestamp'] = pd.to_datetime(first_session['action_timestamp'])

# %%
# groupby id, apply agg func
engage_df = userengagement_df.groupby('user_id', as_index=False).aggregate({'session_id': 'count',
                                                                            'session_length': 'mean',
                                                                            'logged_in_count': 'mean',
                                                                            'view_count': 'mean',
                                                                            'click_count': 'mean',
                                                                            })
# rename columns                                                                        
engage_df.columns = ['user_id', 'session_count', 'avg_session_length', 'avg_logged_in_count', 'avg_views_count', 'avg_clicks_count']

# %%
userengagement_df.shape
# Out:
# (1176858, 42)

# %%
engage_df.head()
# Out:
#                                     user_id  session_count  \
# 0  0000485dbdc19e76bedcaf155b4de9491f414a27              1
# 1  00008fb52ca81c6767db31f58ea37e7229c372e1              1
# 2  000091252c68230bd55a9abda98896c8610994bc              6
# 3  000091d428154729cbf338d4f51aa95af254d342              2
# 4  0000b28d30dd9cf2424e83822b2877fec98b7de5              5
#
#    avg_session_length  avg_logged_in_count  avg_views_count  avg_clicks_count
# 0           704.00000              2.00000          4.00000           0.00000
# 1           751.00000              0.00000         16.00000           6.00000
# 2           361.66667              0.83333          9.00000          12.16667
# 3           965.00000              1.00000          8.00000           6.50000
# 4           100.60000              0.80000          4.40000           4.80000

# %%
engage_df.describe()
# Out:
#        session_count  avg_session_length  avg_logged_in_count  \
# count   285141.00000        285141.00000         285141.00000
# mean         4.12728           375.37432              0.92981
# std          7.09220          1756.40053              0.45096
# min          1.00000             0.00000              0.00000
# 25%          1.00000           160.20000              0.68182
# 50%          2.00000           273.00000              1.00000
# 75%          4.00000           452.00000              1.00000
# max        323.00000        784816.00000             26.00000
#
#        avg_views_count  avg_clicks_count
# count     285141.00000      285141.00000
# mean           5.38466           7.19840
# std            4.27515           8.98738
# min            0.00000           0.00000
# 25%            3.00000           1.33333
# 50%            4.00000           4.78571
# 75%            6.66667           9.87500
# max          164.00000         290.00000

# %%
# drop user with avg session length >= 20,000s --- that's 5.5h
engage_df.loc[(engage_df['avg_session_length'] >= 20000), :]
# Out:
#                                          user_id  session_count  \
# 3874    037c0460cf2eb0bedb2573a3f258cf8a2bd85ca0             51
# 7251    068200869677fae76484a13befdd8f7c9375e896              6
# 268288         30896.00000              1.13333          4.66667
# 275322         73832.15385              1.15385          9.23077
# 279001         23588.45455              1.00000         13.18182
# 279654         25422.50000              1.00000          9.33333
#
#         avg_clicks_count
# 3874             2.03922
# 7251             4.50000
# 9239             6.41176
# 9630             8.14286
# 11456            8.00000
# 13839            3.33333
# 15002            3.15385
# 17411            7.00000
# 23312            4.80000
# 31651           11.50000
# 47177            5.44444
# 60664           14.00000
# 66840            3.50000
# 66949            4.86667
# 69695           19.00000
# 73963            6.33333
# 79693            2.60000
# 80450            5.76923
# 83213            4.26316
# 93479            9.11111
# 94814           15.00000
# 102938          22.00000
# 104116          13.50000
# 104354           9.00000
# 115811           4.23077
# 123286           3.77778
# 124319           3.70000
# 128932           3.28571
# 129274           6.05882
# 133223           2.00000
# 143244           2.78571
# 145043           3.81818
# 151442          16.80000
# 151470          15.25000
# 152194           6.00000
# 153163           4.75000
# 153801           7.28571
# 154796           5.35000
# 158311           3.09524
# 192928           6.00000
# 196459           4.25000
# 207657           4.11111
# 209431           1.45455
# 210557          12.68750
# 212637           2.46429
# 218768           3.25000
# 222993           5.33333
# 224237           5.22222
# 243160           2.29167
# 245270           6.56000
# 246294           7.00000
# 253096           2.00000
# 259118           2.69231
# 261411           8.00000
# 268288           3.86667
# 275322          10.07692
# 279001          11.18182
# 279654           8.83333

# %%
# final data for clustering
engage_df = engage_df.loc[engage_df['avg_session_length'] < 20000, :]

# %%
engage_df.describe()
# Out:
#        session_count  avg_session_length  avg_logged_in_count  \
# count   285083.00000        285083.00000         285083.00000
# mean         4.12584           362.80296              0.92978
# std          7.09106           395.38635              0.45099
# min          1.00000             0.00000              0.00000
# 25%          1.00000           160.16667              0.68182
# 50%          2.00000           273.00000              1.00000
# 75%          4.00000           452.00000              1.00000
# max        323.00000         19874.59091             26.00000
#
#        avg_views_count  avg_clicks_count
# count     285083.00000      285083.00000
# mean           5.38430           7.19850
# std            4.27500           8.98806
# min            0.00000           0.00000
# 25%            3.00000           1.33333
# 50%            4.00000           4.78571
# 75%            6.66667           9.87500
# max          164.00000         290.00000

# %%
# plot distributions
fig, ax = plt.subplots(2, 3, figsize=(20,10))
#plt.subplot(2, 3, i)
sns.distplot(engage_df['session_count'], ax=ax[0, 0])
sns.distplot(engage_df['avg_session_length'], ax=ax[0, 1])
sns.distplot(engage_df['avg_logged_in_count'], ax=ax[1, 0])
sns.distplot(engage_df['avg_views_count'], ax=ax[1, 1])
sns.distplot(engage_df['avg_clicks_count'], ax=ax[1, 2])
fig.delaxes(ax[0, 2])

# trends are basically the same -- poisson dist
# why multiple logins in one session?

# %% [markdown]
# ## 1 Clustering

# %%
# exclude user_id from input
engage_df2 = engage_df.iloc[:, 1:].copy()

# standardization
scl = StandardScaler().fit(engage_df2)
engage_df2[:] = scl.transform(engage_df2[:])
engage_df2.describe()
# Out:
#        session_count  avg_session_length  avg_logged_in_count  \
# count   285083.00000        285083.00000         285083.00000
# mean         0.00000            -0.00000             -0.00000
# std          1.00000             1.00000              1.00000
# min         -0.44082            -0.91759             -2.06166
# 25%         -0.44082            -0.51250             -0.54983
# 50%         -0.29979            -0.22713              0.15570
# 75%         -0.01775             0.22560              0.15570
# max         44.96852            49.34875             55.58958
#
#        avg_views_count  avg_clicks_count
# count     285083.00000      285083.00000
# mean          -0.00000           0.00000
# std            1.00000           1.00000
# min           -1.25949          -0.80090
# 25%           -0.55773          -0.65255
# 50%           -0.32381          -0.26844
# 75%            0.29997           0.29778
# max           37.10313          31.46419

# %%
engage_df2.head()
# Out:
#    session_count  avg_session_length  avg_logged_in_count  avg_views_count  \
# 0       -0.44082             0.86295              2.37305         -0.32381
# 1       -0.44082             0.98182             -2.06166          2.48321
# 2        0.26430            -0.00287             -0.21386          0.84578
# 3       -0.29979             1.52306              0.15570          0.61186
# 4        0.12328            -0.66316             -0.28777         -0.23025
#
#    avg_clicks_count
# 0          -0.80090
# 1          -0.13334
# 2           0.55275
# 3          -0.07771
# 4          -0.26685

# %%
# choosing k: elbow method
distortions = []
K = range(1,11)
for k in K:
 
    # Create a kmeans model on our data, using k clusters.  random_state helps ensure that the algorithm returns the same results each time.
    kmeans_model = KMeans(n_clusters=k, init='k-means++', random_state=1).fit(engage_df2)
    
    # These are our fitted labels for clusters -- the first cluster has label 0, and the second has label 1.
    labels = kmeans_model.labels_
 
    # Sum of distances of samples to their closest cluster center
    interia = kmeans_model.inertia_
    print("k:",k, " cost:", interia)
    distortions.append(interia)
# Out:
# k: 1  cost: 1425414.9999999993
# k: 2  cost: 1054954.1778879205
# k: 3  cost: 899033.351566759
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-370e7b5d2aae> in <module>()
#       5
#       6     # Create a kmeans model on our data, using k clusters.  random_state helps ensure that the algorithm returns the same results each time.
# ----> 7     kmeans_model = KMeans(n_clusters=k, init='k-means++', random_state=1).fit(engage_df2)
#       8
#       9     # These are our fitted labels for clusters -- the first cluster has label 0, and the second has label 1.
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y)
#     894                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     895                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 896                 return_n_iter=True)
#     897         return self
#     898
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     344                 X, n_clusters, max_iter=max_iter, init=init, verbose=verbose,
#     345                 precompute_distances=precompute_distances, tol=tol,
# --> 346                 x_squared_norms=x_squared_norms, random_state=random_state)
#     347             # determine if these results are the best so far
#     348             if best_inertia is None or inertia < best_inertia:
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in _kmeans_single_elkan(X, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     398         print('Initialization complete')
#     399     centers, labels, n_iter = k_means_elkan(X, n_clusters, centers, tol=tol,
# --> 400                                             max_iter=max_iter, verbose=verbose)
#     401     inertia = np.sum((X - centers[labels]) ** 2, dtype=np.float64)
#     402     return labels, inertia, centers, n_iter
#
# sklearn/cluster/_k_means_elkan.pyx in sklearn.cluster._k_means_elkan.k_means_elkan()
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     161
#     162 # Pairwise distances
# --> 163 def euclidean_distances(X, Y=None, Y_norm_squared=None, squared=False,
#     164                         X_norm_squared=None):
#     165     """
#
# KeyboardInterrupt:

# %%
# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-1bd2066c4704> in <module>()
#       1 # Plot the elbow
# ----> 2 plt.plot(K, distortions, 'bx-')
#       3 plt.xlabel('k')
#       4 plt.ylabel('Distortion')
#       5 plt.title('The Elbow Method showing the optimal k')
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     383             x, y = index_of(tup[-1])
#     384
# --> 385         x, y = self._xy_from_xy(x, y)
#     386
#     387         if self.command == 'plot':
#
# ~/miniconda2/envs/py3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     242         if x.shape[0] != y.shape[0]:
#     243             raise ValueError("x and y must have same first dimension, but "
# --> 244                              "have shapes {} and {}".format(x.shape, y.shape))
#     245         if x.ndim > 2 or y.ndim > 2:
#     246             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (3,)

# %% [markdown]
# When K increases, the centroids are closer to the clusters centroids.
#
# The improvements will decline, at some point rapidly, creating the elbow shape.
#
# That point is the optimal value for K.

# %%
#Cluster the data
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=1).fit(engage_df2) 
labels = kmeans.labels_

#Glue back to originaal data
engage_df2['cluster'] = labels
engage_df2.head()
# Out:
#    session_count  avg_session_length  avg_logged_in_count  avg_views_count  \
# 0       -0.44082             0.86295              2.37305         -0.32381
# 1       -0.44082             0.98182             -2.06166          2.48321
# 2        0.26430            -0.00287             -0.21386          0.84578
# 3       -0.29979             1.52306              0.15570          0.61186
# 4        0.12328            -0.66316             -0.28777         -0.23025
#
#    avg_clicks_count  cluster
# 0          -0.80090        2
# 1          -0.13334        2
# 2           0.55275        2
# 3          -0.07771        2
# 4          -0.26685        0

# %%
# Aggregate by cluster
engage_df2_cluster = engage_df2.groupby(['cluster']).aggregate({'session_count': 'mean',
                                                                'avg_session_length': 'mean',
                                                                'avg_logged_in_count': 'mean',
                                                                'avg_views_count': 'mean',
                                                                'avg_clicks_count': 'mean',
                                                                'cluster': 'count'
                                                                })

# %%
# rename count
engage_df2_cluster.rename(columns={'cluster':'counts'}, inplace=True)
#engage_df2_cluster.reset_index(inplace=True)
engage_df2_cluster
# Out:
#          session_count  avg_session_length  avg_logged_in_count  \
# cluster
# 0             -0.12592            -0.30009             -0.42101
# 1             -0.34587             1.68987              1.11069
# 2             -0.23192             0.35024              0.59430
# 3              3.19054            -0.52074             -0.15834
#
#          avg_views_count  avg_clicks_count  counts
# cluster
# 0               -0.49712          -0.46040  163205
# 1                2.88271           2.87737   14278
# 2                0.47773           0.39546   92861
# 3               -0.29778          -0.18084   14739

# %% [markdown]
# ### Plot clusters in 2d
# PCA & tSNE

# %%
X = engage_df2.iloc[:,:5]
y = engage_df2.iloc[:,5]

# %%
X.head()
# Out:
#    session_count  avg_session_length  avg_logged_in_count  avg_views_count  \
# 0       -0.44082             0.86295              2.37305         -0.32381
# 1       -0.44082             0.98182             -2.06166          2.48321
# 2        0.26430            -0.00287             -0.21386          0.84578
# 3       -0.29979             1.52306              0.15570          0.61186
# 4        0.12328            -0.66316             -0.28777         -0.23025
#
#    avg_clicks_count
# 0          -0.80090
# 1          -0.13334
# 2           0.55275
# 3          -0.07771
# 4          -0.26685

# %%
# pca
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

# %%
X_pca = pd.DataFrame(np.c_[X_r, engage_df2['cluster']], columns = ['pc1', 'pc2', 'cluster'])
X_pca['cluster'] = X_pca['cluster'].astype('int')

# %%
X_pca.head()
# Out:
#        pc1      pc2  cluster
# 0  0.71810 -0.86080        2
# 1  1.01622 -0.25242        2
# 2  0.68686  0.50809        2
# 3  1.03105 -0.55812        2
# 4 -0.68283  0.17767        0

# %%
import seaborn as sns
sns.scatterplot(x=X_pca['pc1'], y= X_pca['pc2'], hue = X_pca['cluster'])

# %%
# tsne: it's gonna take a long time????

import time

from sklearn.manifold import TSNE

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
X_r = tsne.fit_transform(X.values)

print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

# %%
X_tsne = pd.DataFrame(np.c_[X_r, engage_df2['cluster']], columns = ['pc1', 'pc2', 'cluster'])
X_tsne['cluster'] = X_tsne['cluster'].astype('int')

# %%
X_tsne.head()
# Out:
#         pc1      pc2  cluster
# 0 -19.22033 -8.37627        2
# 1  -8.37689  7.63914        2
# 2  -5.43460  6.33245        2
# 3  -7.29777 -9.37570        2
# 4   2.31247  8.44551        0

# %%
sns.scatterplot(x=X_tsne['pc1'], y= X_tsne['pc2'], hue = X_tsne['cluster'])

# %% [markdown]
# ## Interpretations

# %%
df = engage_df2_cluster
df.head()
# Out:
#          session_count  avg_session_length  avg_logged_in_count  \
# cluster
# 0             -0.12592            -0.30009             -0.42101
# 1             -0.34587             1.68987              1.11069
# 2             -0.23192             0.35024              0.59430
# 3              3.19054            -0.52074             -0.15834
#
#          avg_views_count  avg_clicks_count  counts
# cluster
# 0               -0.49712          -0.46040  163205
# 1                2.88271           2.87737   14278
# 2                0.47773           0.39546   92861
# 3               -0.29778          -0.18084   14739

# %% [markdown]
# ### Spider Plot

# %%
# minmax scaling so as all clusters is visible in the same plot
df_spider = df.iloc[:,1:-1]

scl = MinMaxScaler().fit(df_spider)
df_spider[:] = scl.transform(df_spider[:])
df_spider.describe()
# Out:
#        avg_session_length  avg_logged_in_count  avg_views_count  \
# count             4.00000              4.00000          4.00000
# mean              0.37345              0.45859          0.33685
# std               0.44994              0.45738          0.45927
# min               0.00000              0.00000          0.00000
# 25%               0.07486              0.12862          0.04424
# 50%               0.24691              0.41718          0.17371
# 75%               0.54550              0.74715          0.46633
# max               1.00000              1.00000          1.00000
#
#        avg_clicks_count
# count           4.00000
# mean            0.33504
# std             0.45598
# min             0.00000
# 25%             0.06282
# 50%             0.17009
# 75%             0.44231
# max             1.00000

# %%
# exclude counts
# ------- PART 1: Create background

# number of variable
categories=list(df_spider)[:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([0.25,0.50,0.75,1.00], ["0.25","0.50","0.75","1.00"], color="grey", size=7)
plt.ylim(0,1)

 
# ------- PART 2: Add plots
for i in range(len(df_spider)):
    values=df_spider.loc[i].values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, linewidth=1, linestyle='solid', label="cluster "+str(i))
    ax.fill(angles, values, 'r', alpha=0.1)
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.savefig('radar.png')

# %%
df_spider.head()
# Out:
#          avg_session_length  avg_logged_in_count  avg_views_count  \
# cluster
# 0                   0.09982              0.00000          0.00000
# 1                   1.00000              1.00000          1.00000
# 2                   0.39400              0.66287          0.28843
# 3                   0.00000              0.17149          0.05898
#
#          avg_clicks_count
# cluster
# 0                 0.00000
# 1                 1.00000
# 2                 0.25642
# 3                 0.08376

# %%
df_barplot.head()
# Out:
#    cluster             metrice    value
# 0        0       session_count -0.12592
# 1        1       session_count -0.34587
# 2        2       session_count -0.23192
# 3        3       session_count  3.19054
# 4        0  avg_session_length -0.30009

# %% [markdown]
# ### Bar Plot

# %%
df_barplot = pd.melt(df.iloc[:,:-1].reset_index(), id_vars="cluster", var_name="metrice", value_name="value")

# %%
sns.set_palette('Set1')
plt.subplots(figsize=(10,6))
sns.barplot(x="cluster", y="value", hue="metrice", data=df_barplot)
plt.savefig('bar.png')

# %%
df.head()
# Out:
#          session_count  avg_session_length  avg_logged_in_count  \
# cluster
# 0             -0.12592            -0.30009             -0.42101
# 1             -0.34587             1.68987              1.11069
# 2             -0.23192             0.35024              0.59430
# 3              3.19054            -0.52074             -0.15834
#
#          avg_views_count  avg_clicks_count  counts
# cluster
# 0               -0.49712          -0.46040  163205
# 1                2.88271           2.87737   14278
# 2                0.47773           0.39546   92861
# 3               -0.29778          -0.18084   14739

# %% [markdown]
# login & logout immediately, explore site, apply for a card/loan, etc.
#
# different patterns of engagement

# %% [markdown]
# ## 2 User Profile for each Cluster

# %%
# user and their corresponding clusters
engage_df['cluster'] = labels
engage_df.head()
# Out:
#                                     user_id  session_count  \
# 0  0000485dbdc19e76bedcaf155b4de9491f414a27              1
# 1  00008fb52ca81c6767db31f58ea37e7229c372e1              1
# 2  000091252c68230bd55a9abda98896c8610994bc              6
# 3  000091d428154729cbf338d4f51aa95af254d342              2
# 4  0000b28d30dd9cf2424e83822b2877fec98b7de5              5
#
#    avg_session_length  avg_logged_in_count  avg_views_count  avg_clicks_count  \
# 0           704.00000              2.00000          4.00000           0.00000
# 1           751.00000              0.00000         16.00000           6.00000
# 2           361.66667              0.83333          9.00000          12.16667
# 3           965.00000              1.00000          8.00000           6.50000
# 4           100.60000              0.80000          4.40000           4.80000
#
#    cluster
# 0        2
# 1        2
# 2        2
# 3        2
# 4        0

# %%
userengagement_df.columns
# Out:
# Index(['Unnamed: 0', 'session_id', 'user_id', 'session_length', 'view_count',
#        'view_aoop_overview_count', 'view_my_credit_count',
#        'view_credit_monitoring_count', 'view_my_recommendations_count',
#        'view_my_borrowing_power_count', 'view_cc_best_cards_count',
#        'view_my_debt_count', 'view_cc_my_borrowing_power_count',
#        'view_cc_approval_odds_count', 'view_cc_details_count',
#        'view_my_credit_report_count', 'view_increase_total_credit_limit_count',
#        'view_cc_marketplace_count', 'view_alert_count', 'click_count',
#        'click_count_credit_card', 'click_count_personal_loan',
#        'click_count_mortgage', 'click_count_credit_repair',
#        'click_count_banking', 'click_count_auto_products', 'click_apply_count',
#        'click_count_credit_card.1', 'click_count_personal_loan.1',
#        'click_count_mortgage.1', 'click_count_credit_repair.1',
#        'click_count_banking.1', 'click_count_auto_products.1',
#        'logged_in_count', 'session_start_timestamp', 'city', 'state',
#        'browser_name', 'browser_version', 'app_version', 'login_platform',
#        'os_name'],
#       dtype='object')

# %%
# join user profile and user_cluster(exclude outlier cluster)
result_df = pd.merge(engage_df.loc[:, ['user_id', 'cluster']], userengagement_df.loc[:, ['user_id', 'login_platform']], how='inner', on=['user_id'])

result_df.head()
# Out:
#                                     user_id  cluster login_platform
# 0  0000485dbdc19e76bedcaf155b4de9491f414a27        2     Mobile Web
# 1  00008fb52ca81c6767db31f58ea37e7229c372e1        2     Mobile Web
# 2  000091252c68230bd55a9abda98896c8610994bc        2     Mobile App
# 3  000091252c68230bd55a9abda98896c8610994bc        2     Mobile App
# 4  000091252c68230bd55a9abda98896c8610994bc        2     Mobile App

# %%
a = pd.DataFrame(result_df.loc[result_df.cluster==3,'login_platform'].value_counts()).reset_index().rename(columns={'index':'login_platform','login_platform':'count'}).sort_values('login_platform')
a['percent'] = a['count'] / sum(a['count'])
a = a.loc[:,['login_platform', 'percent']]
a
# Out:
#   login_platform  percent
# 0     Mobile App  0.50130
# 1     Mobile Web  0.43854
# 2            Web  0.06015

# %%
# plot distributions

fig, ax = plt.subplots(2, 2, figsize=(20,10))
for i in range(4):
    a = pd.DataFrame(result_df.loc[result_df.cluster==i,'login_platform'].value_counts()).reset_index().rename(columns={'index':'login_platform','login_platform':'count'})
    a['percent'] = a['count'] / sum(a['count'])
    a = a.loc[:,['login_platform', 'percent']].sort_values('login_platform')
    sns.barplot(x="login_platform", y="percent",  data=a, ax = ax[i//2,i%2]).set_title('cluster '+str(i))
plt.savefig('cluster-platform.png')
